# %% [markdown]
# # Import Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# # Import dataset

# %%
dataset = pd.read_csv("parkinsons.data")

# %%
dataset.head()
# Out:
#              name  MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# 0  phon_R01_S01_1      119.992       157.302        74.997         0.00784
# 1  phon_R01_S01_2      122.400       148.650       113.819         0.00968
# 2  phon_R01_S01_3      116.682       131.111       111.555         0.01050
# 3  phon_R01_S01_4      116.676       137.871       111.366         0.00997
# 4  phon_R01_S01_5      116.014       141.781       110.655         0.01284
#
#    MDVP:Jitter(Abs)  MDVP:RAP  MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  ...  \
# 0           0.00007   0.00370   0.00554     0.01109       0.04374  ...
# 1           0.00008   0.00465   0.00696     0.01394       0.06134  ...
# 2           0.00009   0.00544   0.00781     0.01633       0.05233  ...
# 3           0.00009   0.00502   0.00698     0.01505       0.05492  ...
# 4           0.00011   0.00655   0.00908     0.01966       0.06425  ...
#
#    Shimmer:DDA      NHR     HNR  status      RPDE       DFA   spread1  \
# ...

# %% [markdown]
# # Exploaring Dataset

# %%
dataset.shape
# Out:
# (195, 24)

# %%
#cheaking for missing values
dataset.isnull().sum()
# Out:
# name                0
# MDVP:Fo(Hz)         0
# MDVP:Fhi(Hz)        0
# MDVP:Flo(Hz)        0
# MDVP:Jitter(%)      0
# MDVP:Jitter(Abs)    0
# MDVP:RAP            0
# MDVP:PPQ            0
# Jitter:DDP          0
# MDVP:Shimmer        0
# MDVP:Shimmer(dB)    0
# Shimmer:APQ3        0
# Shimmer:APQ5        0
# MDVP:APQ            0
# Shimmer:DDA         0
# NHR                 0
# HNR                 0
# status              0
# RPDE                0
# DFA                 0
# spread1             0
# spread2             0
# D2                  0
# PPE                 0
# dtype: int64

# %%
#cheaking for data types
dataset.dtypes
# Out:
# name                 object
# MDVP:Fo(Hz)         float64
# MDVP:Fhi(Hz)        float64
# MDVP:Flo(Hz)        float64
# MDVP:Jitter(%)      float64
# MDVP:Jitter(Abs)    float64
# MDVP:RAP            float64
# MDVP:PPQ            float64
# Jitter:DDP          float64
# MDVP:Shimmer        float64
# MDVP:Shimmer(dB)    float64
# Shimmer:APQ3        float64
# Shimmer:APQ5        float64
# MDVP:APQ            float64
# Shimmer:DDA         float64
# NHR                 float64
# HNR                 float64
# status                int64
# RPDE                float64
# DFA                 float64
# spread1             float64
# spread2             float64
# D2                  float64
# PPE                 float64
# dtype: object

# %%
dataset.describe()
# Out:
#        MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# count   195.000000    195.000000    195.000000      195.000000
# mean    154.228641    197.104918    116.324631        0.006220
# std      41.390065     91.491548     43.521413        0.004848
# min      88.333000    102.145000     65.476000        0.001680
# 25%     117.572000    134.862500     84.291000        0.003460
# 50%     148.790000    175.829000    104.315000        0.004940
# 75%     182.769000    224.205500    140.018500        0.007365
# max     260.105000    592.030000    239.170000        0.033160
#
#        MDVP:Jitter(Abs)    MDVP:RAP    MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  \
# count        195.000000  195.000000  195.000000  195.000000    195.000000
# mean           0.000044    0.003306    0.003446    0.009920      0.029709
# std            0.000035    0.002968    0.002759    0.008903      0.018857
# min            0.000007    0.000680    0.000920    0.002040      0.009540
# ...

# %%
#inspect target variable
dataset['status'].value_counts()
# Out:
# 1    147
# 0     48
# Name: status, dtype: int64

# %%
dataset['status'].value_counts().plot(kind = 'bar' , title = "Target variable")

# %%
dataset.columns
# Out:
# Index(['name', 'MDVP:Fo(Hz)', 'MDVP:Fhi(Hz)', 'MDVP:Flo(Hz)', 'MDVP:Jitter(%)',
#        'MDVP:Jitter(Abs)', 'MDVP:RAP', 'MDVP:PPQ', 'Jitter:DDP',
#        'MDVP:Shimmer', 'MDVP:Shimmer(dB)', 'Shimmer:APQ3', 'Shimmer:APQ5',
#        'MDVP:APQ', 'Shimmer:DDA', 'NHR', 'HNR', 'status', 'RPDE', 'DFA',
#        'spread1', 'spread2', 'D2', 'PPE'],
#       dtype='object')

# %% [markdown]
# No null values.
# Now to understand the correlation and dataset distribution let's create a dataset with unique count data type and null count values.

# %%
df = pd.DataFrame(index = dataset.columns)
df["Unique Count"] = dataset.nunique()
df["Null Count"] = dataset.isnull().sum()
df["Data Type"] = dataset.dtypes

# %%
df
# Out:
#                   Unique Count  Null Count Data Type
# name                       195           0    object
# MDVP:Fo(Hz)                195           0   float64
# MDVP:Fhi(Hz)               195           0   float64
# MDVP:Flo(Hz)               195           0   float64
# MDVP:Jitter(%)             173           0   float64
# MDVP:Jitter(Abs)            19           0   float64
# MDVP:RAP                   155           0   float64
# MDVP:PPQ                   165           0   float64
# Jitter:DDP                 180           0   float64
# MDVP:Shimmer               188           0   float64
# MDVP:Shimmer(dB)           149           0   float64
# Shimmer:APQ3               184           0   float64
# Shimmer:APQ5               189           0   float64
# MDVP:APQ                   189           0   float64
# Shimmer:DDA                189           0   float64
# NHR                        185           0   float64
# HNR                        195           0   float64
# ...

# %%
#cheaking for correlation
dataset.corr()
# Out:
#                   MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# MDVP:Fo(Hz)          1.000000      0.400985      0.596546       -0.118003
# MDVP:Fhi(Hz)         0.400985      1.000000      0.084951        0.102086
# MDVP:Flo(Hz)         0.596546      0.084951      1.000000       -0.139919
# MDVP:Jitter(%)      -0.118003      0.102086     -0.139919        1.000000
# MDVP:Jitter(Abs)    -0.382027     -0.029198     -0.277815        0.935714
# MDVP:RAP            -0.076194      0.097177     -0.100519        0.990276
# MDVP:PPQ            -0.112165      0.091126     -0.095828        0.974256
# Jitter:DDP          -0.076213      0.097150     -0.100488        0.990276
# MDVP:Shimmer        -0.098374      0.002281     -0.144543        0.769063
# MDVP:Shimmer(dB)    -0.073742      0.043465     -0.119089        0.804289
# Shimmer:APQ3        -0.094717     -0.003743     -0.150747        0.746625
# Shimmer:APQ5        -0.070682     -0.009997     -0.101095        0.725561
# ...

# %% [markdown]
# Plot heatmap

# %%
sns.heatmap(dataset.corr(),annot=True, cmap='terrain', linewidths=0.2)
fig=plt.gcf()
fig.set_size_inches(16,14)
plt.show()

# %%
feature = plotcorr['status'] >= 0.25
feature
# Out:
# MDVP:Fo(Hz)         False
# MDVP:Fhi(Hz)        False
# MDVP:Flo(Hz)        False
# MDVP:Jitter(%)       True
# MDVP:Jitter(Abs)     True
# MDVP:RAP             True
# MDVP:PPQ             True
# Jitter:DDP           True
# MDVP:Shimmer         True
# MDVP:Shimmer(dB)     True
# Shimmer:APQ3         True
# Shimmer:APQ5         True
# MDVP:APQ             True
# Shimmer:DDA          True
# NHR                 False
# HNR                 False
# status               True
# RPDE                 True
# DFA                 False
# spread1              True
# spread2              True
# D2                   True
# PPE                  True
# Name: status, dtype: bool

# %% [markdown]
# Remove features which add no value

# %%
#cheaking for outliers
dataset.boxplot()

# %%
rm_features = [
    "MDVP:Fo(Hz)", "MDVP:Fhi(Hz)", "MDVP:Flo(Hz)", "NHR", "HNR", "DFA"
]

# %%
feature_dataset = dataset.drop(rm_features, axis = 1)

# %%
feature_dataset.head()
# Out:
#              name  MDVP:Jitter(%)  MDVP:Jitter(Abs)  MDVP:RAP  MDVP:PPQ  \
# 0  phon_R01_S01_1         0.00784           0.00007   0.00370   0.00554
# 1  phon_R01_S01_2         0.00968           0.00008   0.00465   0.00696
# 2  phon_R01_S01_3         0.01050           0.00009   0.00544   0.00781
# 3  phon_R01_S01_4         0.00997           0.00009   0.00502   0.00698
# 4  phon_R01_S01_5         0.01284           0.00011   0.00655   0.00908
#
#    Jitter:DDP  MDVP:Shimmer  MDVP:Shimmer(dB)  Shimmer:APQ3  Shimmer:APQ5  \
# 0     0.01109       0.04374             0.426       0.02182       0.03130
# 1     0.01394       0.06134             0.626       0.03134       0.04518
# 2     0.01633       0.05233             0.482       0.02757       0.03858
# 3     0.01505       0.05492             0.517       0.02924       0.04005
# 4     0.01966       0.06425             0.584       0.03490       0.04825
#
#    MDVP:APQ  Shimmer:DDA  status      RPDE   spread1   spread2        D2  \
# ...

# %%
feature_dataset.shape
# Out:
# (195, 18)

# %% [markdown]
# # Data visualization

# %%
feature_dataset.hist(figsize=(14,14))
plt.show()

# %%
sns.pairplot(feature_dataset,hue='status')
